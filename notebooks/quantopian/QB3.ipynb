# %%
import pandas
import math
import json
import numpy as np

# %%
url = 'https://www.quandl.com/api/v3/datasets/BCHARTS/BITSTAMPUSD?trim_start=2019-07-01'

# %%
R = '''
{
  "dataset": {
    "id": 11320888,
    "dataset_code": "BITSTAMPUSD",
    "database_code": "BCHARTS",
    "name": "Bitcoin Markets (bitstampUSD)",
    "description": "Daily Bitcoin exchange rate (BTC vs. USD) on Bitstamp. Updated daily at 6:00pm EST. Data is sourced from http://www.bitcoincharts.com . For other Bitcoin data and charts see our Bitcoin markets page (http://www.quandl.com/markets/bitcoin-data).",
    "refreshed_at": "2019-07-14 23:04:15 UTC",
    "newest_available_date": "2019-07-14",
    "oldest_available_date": "2011-09-13",
    "column_names": [
      "Date",
      "Open",
      "High",
      "Low",
      "Close",
      "Volume (BTC)",
      "Volume (Currency)",
      "Weighted Price"
    ],
    "frequency": "daily",
    "type": "Time Series",
    "premium": false,
    "limit": null,
    "transform": null,
    "column_index": null,
    "start_date": "2019-05-25",
    "end_date": "2019-07-14",
    "data": [
      [
        "2019-07-14",
        11382.03,
        11467.3,
        10280.48,
        10412.2,
        10812.91956143,
        115490999.69452,
        10680.834074312
      ],
      [
        "2019-07-13",
        11811.08,
        11846.61,
        10810.0,
        11378.79,
        9391.35341435,
        105947622.15865,
        11281.400825228
      ],
      [
        "2019-07-12",
        11352.74,
        11942.39,
        11083.52,
        11808.91,
        9176.67942993,
        105982547.44891,
        11549.1173314
      ],
      [
        "2019-07-11",
        12101.44,
        12104.97,
        10966.81,
        11349.24,
        18468.68600043,
        212707393.6462,
        11517.19151223
      ],
      [
        "2019-07-10",
        12574.88,
        13200.0,
        11550.0,
        12098.95,
        19838.38994897,
        248386820.65223,
        12520.513070423
      ],
      [
        "2019-07-09",
        12299.94,
        12883.48,
        12030.43,
        12567.23,
        15115.5523839,
        188848935.90091,
        12493.684061593
      ],
      [
        "2019-07-08",
        11478.43,
        12398.0,
        11332.19,
        12286.14,
        11901.90089462,
        142163191.21873,
        11944.578641466
      ],
      [
        "2019-07-07",
        11233.21,
        11627.0,
        11083.76,
        11469.96,
        6683.05546715,
        75851416.718673,
        11349.811039503
      ],
      [
        "2019-07-06",
        10996.82,
        11735.0,
        10982.89,
        11240.0,
        7892.17866812,
        90077908.728894,
        11413.566838364
      ],
      [
        "2019-07-05",
        11144.82,
        11440.0,
        10769.15,
        10997.84,
        11893.4379497,
        132207381.38165,
        11115.993705166
      ],
      [
        "2019-07-04",
        11970.0,
        12061.04,
        11052.74,
        11146.34,
        11185.29420376,
        130996748.89728,
        11711.515719743
      ],
      [
        "2019-07-03",
        10830.1,
        12009.0,
        10830.1,
        11967.43,
        19389.85475767,
        220385744.07776,
        11366.033775502
      ],
      [
        "2019-07-02",
        10581.78,
        10942.63,
        9614.08,
        10828.9,
        20285.24655295,
        206617402.08237,
        10185.599743293
      ],
      [
        "2019-07-01",
        10759.24,
        11200.41,
        9950.0,
        10577.43,
        22917.43710404,
        7150.59429755,
        56100688.224005,
        7845.5979866214
      ],
      [
        "2019-06-09",
        7933.17,
        7966.58,
        7511.41,
        7632.99,
        3895.84810538,
        30121891.877318,
        7731.7931968962
      ],
      [
        "2019-06-08",
        8002.68,
        8061.12,
        7777.67,
        7932.27,
        4870.11556741,
        38536604.546195,
        7912.8727055423
      ],
      [
        "2019-06-07",
        7801.97,
        8134.99,
        7758.93,
        8001.25,
        9012.09615945,
        71665291.076446,
        7952.1223263135
      ],
      [
        "2019-06-06",
        7784.62,
        7878.62,
        7449.68,
        7806.07,
        8738.66635896,
        67238735.506705,
        7694.3932569029
      ],
      [
        "2019-06-05",
        7673.41,
        7924.48,
        7570.9,
        7785.94,
        9193.71188764,
        71403852.939905,
        7766.5967579319
      ],
      [
        "2019-06-04",
        8103.63,
        8103.63,
        7432.84,
        7665.53,
        15485.70215021,
        120977317.95653,
        7812.1945510164
      ],
      [
        "2019-06-03",
        8735.84,
        8745.96,
        8049.22,
        8103.64,
        9955.03261894,
        84089274.151653,
        8446.9109615641
      ],
      [
        "2019-06-02",
        8560.1,
        8833.97,
        8546.01,
        8734.49,
        4263.0361653,
        37098988.768094,
        8702.4804223033
      ],
      [
        "2019-06-01",
        8545.8,
        8624.72,
        8457.33,
        8556.27,
        5167.05130706,
        44144370.366347,
        8543.4356546897
      ],
      [
        "2019-05-31",
        8277.76,
        8589.99,
        8109.74,
        8547.2,
        9957.91006545,
        83009912.016167,
        8336.0776980884
      ],
      [
        "2019-05-30",
        8663.07,
        9096.79,
        8000.0,
        8277.76,
        15259.58792555,
        130901794.23144,
        8578.3308743394
      ],
      [
        "2019-05-29",
        8715.35,
        8762.39,
        8421.12,
        8663.41,
        7584.25785894,
        65411714.731597,
        8624.6691434011
      ],
      [
        "2019-05-28",
        8774.45,
        8817.41,
        8540.94,
        8717.96,
        6144.01124571,
        53514184.125441,
        8709.9749634747
      ],
      [
        "2019-05-27",
        8733.27,
        8939.18,
        8653.68,
        8770.73,
        8948.02467376,
        78657195.09515,
        8790.4535316953
      ],
      [
        "2019-05-26",
        8066.15,
        8802.29,
        7888.91,
        8733.26,
        8526.81164447,
        71863220.700701,
        8427.9122956008
      ],
      [
        "2019-05-25",
        7999.02,
        8158.45,
        7939.76,
        8064.64,
        3361.65325124,
        27074799.566817,
        8054.013172486
      ]
    ],
    "collapse": null,
    "order": null,
    "database_id": 8431
  }
}
'''

# %%
def decay(l, n, v):
    if n<1:
        return
    else:
        nv = v / 2
#         print(n, nv)
        l.append(nv)
        decay(l, n - 1, nv)

def sigmoid(z):
    return 1 / (1 + math.pow(math.e, -(z)))

def decorate(element):
    date = element[0]
    open_ = element[1]
    high = element[2]
    low = element[3]
    close = element[4]
    return {"date" : date, "open" : open_, "high" : high, "close" : close, "low" : low }

def calculateMP(c):
    LW = max(c["high"] - max(c["open"], c["close"]), 0)
    body = max(c["open"], c["close"]) - min(c["open"], c["close"])
    SP = LW / (LW + body)


    SW = max(min(c["open"], c["close"]) - c["low"], 0)
    BP = SW / (SW + body)
    
    c["SP"] = SP
    c["BP"] = BP
    

def triangle_score(p2, p1, idx2, idx1):
    return (1 / (0.001 + abs(p2 - p1)) * (1 / abs(idx2 - idx1)))

# %%
def PRESSURE_LIST(JD):
    DECBs = []

    for jrd in JD:
    #     print(jrd)
        decB = decorate(jrd)
        calculateMP(decB)
        DECBs.append(decB)
    #     print(decB)

    # change the weight list formula 1 / x
    WEIGHTED_LIST = [((l[i[0]]) * i[1]['SP'], l[i[0]] * i[1]['BP'], i[1]['high'], i[1]['low'], i[1]['date'])  for i in enumerate(DECBs)]


    SPLIST = []
    BPLIST = []
    sp_high = 0
    bp_low = 10000000.0

    for j in enumerate(WEIGHTED_LIST):
        k = j[0]
        i = j[1]
        d = j[1][4]
    #     print(i[0], i[1])
        if(i[2] > sp_high):
            sp_high = i[2]
            SPLIST.append((k,sp_high, i[0], d))

        if(i[3] < bp_low):
            bp_low = i[3]
            BPLIST.append((k,bp_low, i[1], d))
            
    return (SPLIST, BPLIST)

# %%
def sentiment_strength(OPEN, HIGH, LOW, CLOSE):
    body = CLOSE - OPEN
    LENGTH = abs(HIGH - LOW)
    if body > 0:
        score = abs(body) / LENGTH
    else:
        score = -1 * abs(body) / LENGTH
    return score * .01

# %%
def sentiment_score(JRDATA):


    # print(SPLIST)
    # print(BPLIST)
    
    SPLIST, BPLIST = PRESSURE_LIST(JRDATA)

    LONG = sum([i[2] for i in SPLIST])
    SHORT = sum([i[2] for i in BPLIST])

#     print("SELLING PRESSURE=", LONG)
#     for i in SPLIST:
#         print(i[0], i[2], i[3])

#     print("BUYING PRESSURE=", SHORT)
#     for i in BPLIST:
#         print(i[0], i[2], i[3])

    PRESSURE_SCORE = sigmoid(LONG - (SHORT))
#     print(PRESSURE_SCORE)

    SPTLIST = []
    RSPLIST = [i for i in reversed(SPLIST)]
    for i in RSPLIST:
        # we want to find the next highest first
        nhigh = 0
        index = -1
        for j in RSPLIST:
            if(i[0] != j[0]):
                if j[1] > nhigh and j[1] < i[1]:
                    nhigh = j[1]
                    index = j[0]
    #                 print((i[3], i[1]), (j[3], j[1]))

        if(index > 0):
#             print(i[0], i[3], i[1], nhigh, index, i[0] - index)
            ts = triangle_score(i[1], nhigh, i[0], index)
    #         print(ts)
            SPTLIST.append(ts)
    SPTSCORE = sum(SPTLIST)
#     print("TRITOP", SPTSCORE)
    BPTLIST = []
    RBPLIST = [i for i in reversed(BPLIST)]
    for i in RBPLIST:
        nlow = 1000000
        index = -1    
        for j in RBPLIST:
            if(i[0] != j[0]):
    #             print((i[3], i[1]), (j[3], j[1]))
    #             print("x", i[1], j[1])
                if(j[1] < nlow and i[1] < j[1]):
                    nlow = j[1]
                    index = j[0]
    #     print(i, nlow, index)

        if(index > 0):
#             print(i[0], i[3], i[1], nlow, index, i[0] - index)
            ts = triangle_score(i[1], nlow, i[0], index)
    #         print(ts)
            BPTLIST.append(ts)

#     print(BPTLIST)
    BPTSCORE = sum(BPTLIST)    
#     print("TRIBOTTOM", BPTSCORE)
    TRI_SCORE = sigmoid(SPTSCORE - BPTSCORE)
#     print(TRI_SCORE)


    OVERALL_SCORE = np.average([PRESSURE_SCORE, TRI_SCORE])
#     print(JRDATA[0][0], OVERALL_SCORE)

    OPEN = JRDATA[0][1]
    HIGH = JRDATA[0][2]
    LOW = JRDATA[0][3]
    CLOSE = JRDATA[0][4]

    S_SCORE = sentiment_strength(OPEN, HIGH, LOW, CLOSE)
#     print("S", S_SCORE)


    OVERALL_SCORE = OVERALL_SCORE + S_SCORE
    return OVERALL_SCORE

# %%
l = []
decay(l, 1000, 2)

# %%
JR = json.loads(R)
JRDATA = JR['dataset']['data']
len(JRDATA)
# Out:
# 51

# %%
# JRDATA = [['2019-07-12',
#   202.44999999999999,
#   204.0,
#   202.19999999999999,
#   203.24000000000001,
#   6,
#   7,
#   8],
#  ['2019-07-11',
#   203.31,
#   204.38999999999999,
#   201.71000000000001,
#   201.74000000000001,
#   6,
#   7,
#   8],
#  ['2019-07-10',
#   201.84999999999999,
#   203.72999999999999,
#   201.56,
#   203.21000000000001,
#   6,
#   7,
#   8],
#  ['2019-07-09',
#   199.19999999999999,
#   201.50999999999999,
#   198.81,
#   201.22,
#   6,
#   7,
#   8],
#  ['2019-07-08',
#   200.81,
#   201.40000000000001,
#   198.41,
#   200.00999999999999,
#   6,
#   7,
#   8],
#  ['2019-07-05',
#   203.34999999999999,
#   205.08000000000001,
#   202.90000000000001,
#   204.25,
#   6,
#   7,
#   8],
#  ['2019-07-03', 203.28, 204.44, 202.69, 204.41, 6, 7, 8],
#  ['2019-07-02',
#   201.41,
#   203.13200000000001,
#   201.36000000000001,
#   202.71000000000001,
#   6,
#   7,
#   8],
#  ['2019-07-01',
#   203.16999999999999,
#   204.49000000000001,
#   200.65000000000001,
#   201.68000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-28',
#   198.68000000000001,
#   199.495,
#   197.05000000000001,
#   197.91999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-27',
#   200.28999999999999,
#   201.56999999999999,
#   199.56999999999999,
#   199.72999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-26',
#   197.77000000000001,
#   200.99000000000001,
#   197.34999999999999,
#   199.80000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-25',
#   198.43000000000001,
#   199.25999999999999,
#   195.28999999999999,
#   195.56999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-24',
#   198.53999999999999,
#   200.16,
#   198.16999999999999,
#   198.55000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-21',
#   198.80000000000001,
#   200.84999999999999,
#   198.15000000000001,
#   198.80000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-20',
#   200.37,
#   200.61000000000001,
#   198.03,
#   199.37899999999999,
#   6,
#   7,
#   8],
#  ['2019-06-19',
#   199.68000000000001,
#   199.88,
#   197.31,
#   197.86000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-18',
#   196.05000000000001,
#   200.28999999999999,
#   195.21000000000001,
#   198.5,
#   6,
#   7,
#   8],
#  ['2019-06-17',
#   192.90000000000001,
#   194.96000000000001,
#   192.16999999999999,
#   193.94999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-14',
#   191.54499999999999,
#   193.58600000000001,
#   190.30000000000001,
#   192.74000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-13',
#   194.69999999999999,
#   196.78999999999999,
#   193.59999999999999,
#   194.74000000000001,
#   6,
#   7,
#   8],
#  ['2019-06-12',
#   193.94999999999999,
#   195.97,
#   193.38499999999999,
#   194.19,
#   6,
#   7,
#   8],
#  ['2019-06-11',
#   194.86000000000001,
#   196.0,
#   193.59999999999999,
#   194.81,
#   6,
#   7,
#   8],
#  ['2019-06-10', 191.81, 195.37, 191.62, 192.5, 6, 7, 8],
#  ['2019-06-07',
#   186.50999999999999,
#   191.91999999999999,
#   185.77000000000001,
#   190.13999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-06',
#   183.08000000000001,
#   185.47,
#   182.149,
#   185.22999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-05',
#   184.28,
#   184.99000000000001,
#   181.13999999999999,
#   182.541,
#   6,
#   7,
#   8],
#  ['2019-06-04',
#   175.44,
#   179.83000000000001,
#   174.52000000000001,
#   179.66999999999999,
#   6,
#   7,
#   8],
#  ['2019-06-03',
#   175.59999999999999,
#   177.91999999999999,
#   170.27000000000001,
#   173.28,
#   6,
#   7,
#   8],
#  ['2019-05-31',
#   176.22999999999999,
#   177.99000000000001,
#   174.99000000000001,
#   175.0,
#   6,
#   7,
#   8],
#  ['2019-05-30',
#   177.94999999999999,
#   179.22999999999999,
#   176.66999999999999,
#   178.25,
#   6,
#   7,
#   8],
#  ['2019-05-29',
#   176.41999999999999,
#   179.34999999999999,
#   176.0,
#   177.34999999999999,
#   6,
#   7,
#   8],
#  ['2019-05-28',
#   178.91999999999999,
#   180.59,
#   177.91,
#   178.16999999999999,
#   6,
#   7,
#   8],
#  ['2019-05-24',
#   180.19999999999999,
#   182.13999999999999,
#   178.62,
#   179.06,
#   6,
#   7,
#   8],
#  ['2019-05-23',
#   179.80000000000001,
#   180.53999999999999,
#   177.81,
#   179.66999999999999,
#   6,
#   7,
#   8],
#  ['2019-05-22',
#   184.66,
#   185.71000000000001,
#   182.55000000000001,
#   182.78999999999999,
#   6,
#   7,
#   8],
#  ['2019-05-21', 185.22, 188.0, 184.69999999999999, 186.59, 6, 7, 8],
#  ['2019-05-20',
#   183.52000000000001,
#   184.34899999999999,
#   180.28399999999999,
#   183.09,
#   6,
#   7,
#   8],
#  ['2019-05-17',
#   186.93000000000001,
#   190.90000000000001,
#   186.75999999999999,
#   188.97999999999999,
#   6,
#   7,
#   8],
#  ['2019-05-16',
#   189.91,
#   199.37200000000001,
#   195.45699999999999,
#   198.11699999999999,
#   6,
#   7,
#   8],
#  ['2019-04-11',
#   200.08000000000001,
#   200.22900000000001,
#   197.68199999999999,
#   198.17699999999999,
#   6,
#   7,
#   8],
#  ['2019-04-10',
#   197.91800000000001,
#   199.97,
#   197.41999999999999,
#   199.88999999999999,
#   6,
#   7,
#   8],
#  ['2019-04-09',
#   199.55199999999999,
#   202.072,
#   198.46600000000001,
#   198.73500000000001,
#   6,
#   7,
#   8],
#  ['2019-04-08',
#   195.666,
#   199.46199999999999,
#   195.58699999999999,
#   199.31200000000001,
#   6,
#   7,
#   8],
#  ['2019-04-05', 195.696, 196.34399999999999, 195.178, 196.214, 6, 7, 8],
#  ['2019-04-04',
#   194.04300000000001,
#   195.61699999999999,
#   192.399,
#   194.96899999999999,
#   6,
#   7,
#   8],
#  ['2019-04-03',
#   192.50899999999999,
#   195.74600000000001,
#   192.40899999999999,
#   194.601,
#   6,
#   7,
#   8],
#  ['2019-04-02',
#   190.357,
#   193.714,
#   190.31700000000001,
#   193.29599999999999,
#   6,
#   7,
#   8],
#  ['2019-04-01',
#   190.905,
#   190.94499999999999,
#   187.65700000000001,
#   190.506,
#   6,
#   7,
#   8],
#  ['2019-03-29',
#   189.102,
#   189.351,
#   187.81700000000001,
#   189.21100000000001,
#   6,
#   7,
#   8],
#  ['2019-03-28',
#   188.22499999999999,
#   188.83199999999999,
#   186.81100000000001,
#   187.98599999999999,
#   6,
#   7,
#   8],
#  ['2019-03-27',
#   188.02600000000001,
#   189.03200000000001,
#   185.834,
#   187.74700000000001,
#   6,
#   7,
#   8],
#  ['2019-03-26',
#   190.929,
#   192.13999999999999,
#   183.87200000000001,
#   186.07300000000001,
#   6,
#   7,
#   8],
#  ['2019-03-25',
#   190.77500000000001,
#   191.244,
#   185.88399999999999,
#   188.04599999999999,
#   6,
#   7,
#   8]]

# %%
JRDATA
# Out:
# [['2019-07-13',
#   11811.08,
#   11846.61,
#   10810.0,
#   11282.35,
#   9182.08566618,
#   103582023.26158,
#   11280.881820032],
#  ['2019-07-12',
#   11352.74,
#   11942.39,
#   11083.52,
#   11808.91,
#   9176.67942993,
#   105982547.44891,
#   11549.1173314],
#  ['2019-07-11',
#   12101.44,
#   12104.97,
#   10966.81,
#   11349.24,
#   18468.68600043,
#   212707393.6462,
#   11517.19151223],
#  ['2019-07-10',
#   12574.88,
#   13200.0,
#   11550.0,
#   12098.95,
#   19838.38994897,
#   248386820.65223,
#   12520.513070423],
#  ['2019-07-09',
#   12299.94,
#   12883.48,
#   12030.43,
#   12567.23,
#   15115.5523839,
#   188848935.90091,
#   12493.684061593],
#  ['2019-07-08',
#   11478.43,
#   12398.0,
#   11332.19,
#   12286.14,
#   11901.90089462,
#   142163191.21873,
#   11944.578641466],
#  ['2019-07-07',
#   11233.21,
#   11627.0,
#   11083.76,
#   11469.96,
#   6683.05546715,
#   75851416.718673,
#   11349.811039503],
#  ['2019-07-06',
#   10996.82,
#   11735.0,
# ...

# %%
def findOptimumParameter(ntrades, nlength):
    correct_ans = 0
    total = 0.000001
    earnings = []

    raw_score = 0
    raw_total = 0.000001

    short_correct_ans = 0
    short_total = 0.00001

    for i in [i for i in reversed(range(ntrades))]:
        data = JRDATA[i:][:nlength]
        next_one = i - 1
        if(next_one > 0):
            next_data = JRDATA[next_one:][0]
            next_day_sentiment = next_data[4] - next_data[1] 
            score = sentiment_score(data)

            
            if(score > .5):        
                if(score > .5 and next_day_sentiment > 0):
                    print(data[0])
                    correct_ans += 1

                earnings.append(next_day_sentiment)
                total += 1     


            if(score < .5):        
                if(score < .5 and next_day_sentiment < 0):
                    short_correct_ans += 1

                short_total += 1  

            # calculate raw score
            if(score > .5 and next_day_sentiment > 0):
                raw_score += 1
            if(score < .5 and next_day_sentiment < 0):
                raw_score += 1
            raw_total += 1

    total_earnings = (sum([i for i in map(lambda x: abs(x), earnings)]))

    print("S", short_correct_ans, short_total, short_correct_ans / short_total)

    print("B", correct_ans, total, correct_ans / total, sum(earnings))

#     print(raw_score / raw_total) 

    return (sigmoid((correct_ans / total) - short_correct_ans / short_total))

# %%
top_score = 0
index = 0
top_scores = []
optimized_extent = 0
optimized_trades = 0

for extent in range(30, 90):
    for ntrades in range(10, 30):
        tmp_score = (findOptimumParameter(ntrades, extent))
#         print(tmp_score)
        if tmp_score > top_score:
            top_score = tmp_score
            optimized_trades = ntrades
            optimized_extent = extent
#             index = i
            
print(extent, top_score, optimized_trades, optimized_extent)
# Out:
# ['2019-07-06', 10996.82, 11735.0, 10982.89, 11240.0, 7892.17866812, 90077908.728894, 11413.566838364]
# ['2019-07-07', 11233.21, 11627.0, 11083.76, 11469.96, 6683.05546715, 75851416.718673, 11349.811039503]
# S 3 6.00001 0.4999991666680556
# B 2 2.000001 0.99999950000025 1044.4599999999991
# ['2019-07-06', 10996.82, 11735.0, 10982.89, 11240.0, 7892.17866812, 90077908.728894, 11413.566838364]
# ['2019-07-07', 11233.21, 11627.0, 11083.76, 11469.96, 6683.05546715, 75851416.718673, 11349.811039503]
# S 4 7.00001 0.571427755103207
# B 2 2.000001 0.99999950000025 1044.4599999999991
# ['2019-07-06', 10996.82, 11735.0, 10982.89, 11240.0, 7892.17866812, 90077908.728894, 11413.566838364]
# ['2019-07-07', 11233.21, 11627.0, 11083.76, 11469.96, 6683.05546715, 75851416.718673, 11349.811039503]
# S 4 8.00001 0.4999993750007813
# B 2 2.000001 0.99999950000025 1044.4599999999991
# ['2019-07-06', 10996.82, 11735.0, 10982.89, 11240.0, 7892.17866812, 90077908.728894, 11413.566838364]
# ...

# %%
data = JRDATA[0:][:optimized_extent]

# %%
score = sentiment_score(data)
print(top_score, score)
if top_score > .5 and score > .5:
    print("GO LONG")  
elif top_score < .5 and score < .5:
    print("GO SHORT")
else:
    print("NO TRADE")
# Out:
# 0.6500018788551035 0.5022252313877174
# GO LONG
